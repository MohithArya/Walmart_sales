# %%
import pandas as pd

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv(r"C:\MOHITH\CDA Projects\WALMART\walmart\Walmart.csv") 
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity        date      time payment_method  rating  profit_margin
# 0       7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48

# %%
df
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.shape
# Out:
# (10051, 11)

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
# getting duplicates
df.duplicated().sum()
# Out:
# 51

# %%
df[df.duplicated(keep=False)]
# Out:
#        invoice_id   Branch         City             category unit_price  \
# 9949         9950  WALM038   Sugar Land  Fashion accessories        $17
# 9950         9951  WALM082      Weslaco   Home and lifestyle        $58
# 9951         9952  WALM035   San Angelo  Fashion accessories        $76
# 9952         9953  WALM084      Schertz   Home and lifestyle        $68
# 9953         9954  WALM046       Temple  Fashion accessories        $40
# 9954         9955  WALM054      Sherman   Home and lifestyle        $61
# 9955         9956  WALM003  San Antonio  Fashion accessories        $17
# 9956         9957  WALM029   Round Rock   Home and lifestyle        $53
# 9957         9958  WALM084      Schertz  Fashion accessories        $35
# 9958         9959  WALM065   Texas City   Home and lifestyle        $36
# 9959         9960  WALM054      Sherman  Fashion accessories        $42
# 9960         9961  WALM046       Temple   Home and lifestyle        $70
# ...

# %%
# droping the duplicates
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [invoice_id, Branch, City, category, unit_price, quantity, date, time, payment_method, rating, profit_margin]
# Index: []

# %%
df.shape
# Out:
# (10000, 11)

# %%
# Handling missing values
# getting null values
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
# changing datatypes
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price         object
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df["unit_price"].str.replace('$','').astype(float)
# Out:
# 0       74.69
# 1       15.28
# 2       46.33
# 3       58.22
# 4       86.31
# 5       85.39
# 6       68.84
# 7       73.56
# 8       36.26
# 9       54.84
# 10      14.48
# 11      25.51
# 12      46.95
# 13      43.19
# 14      71.38
# 15      93.72
# 16      68.93
# 17      72.61
# 18      54.67
# 19      40.30
# 20      86.04
# 21      87.98
# 22      33.20
# 23      34.56
# 24      88.63
# 25      52.59
# 26      33.52
# 27      87.67
# 28      88.36
# 29      24.89
# 30      94.13
# 31      78.07
# 32      83.78
# 33      96.58
# 34      99.42
# 35      68.12
# 36      62.62
# 37      60.88
# 38      54.92
# 39      30.12
# 40      86.72
# 41      56.11
# 42      69.12
# 43      98.70
# 44      15.37
# 45      93.96
# 46      56.69
# 47      20.01
# 48      18.93
# 49      82.63
# 50      91.40
# 51      44.59
# 52      17.87
# 53      15.43
# 54      16.16
# 55      85.98
# 56      44.34
# 57      89.60
# 58      72.35
# 59      30.61
# 60      24.74
# 61      55.73
# ...

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity        date      time payment_method  rating  profit_margin
# 0       7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48

# %%
df['unit_price'] = df["unit_price"].str.replace('$','').astype(float)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity        date      time payment_method  rating  profit_margin
# 0       7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price        float64
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %%
df['Amount'] = df['unit_price'] * df['quantity']
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity        date      time payment_method  rating  profit_margin  \
# 0       7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48
#
#    Amount
# 0  522.83
# 1   76.40
# 2  324.31
# 3  465.76
# 4  604.17

# %%
! pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/45.0 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 551.3 kB/s eta 0:00:00
# ...

# %%
# !pip install sqlalchemy

# %%
import pymysql
from sqlalchemy import create_engine

# %%
# mysql connection

engine_mysql = create_engine("mysql+pymysql://root:Hsmap%40172@localhost:3306/walmart")

try:
    engine_mysql
    print("Connection Successed to mysql")
except:
    print("Unable to connect")
# Out:
# Connection Successed to mysql

# %%
#host = localhost
#port = 3306
#user = root
#password = *********

# %%
df.to_sql(name = 'walmart', con = engine_mysql, if_exists = 'append',index = False)
# Out:
# 9969
